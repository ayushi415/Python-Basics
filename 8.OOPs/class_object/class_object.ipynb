# %%
### Attritube and Instance variables
# Attributes, also known as instance variable, are properties associated with objects

audi.windows = 4
print(audi.windows)

tata = Car()
tata.doors = 4
print(tata.windows) # this will raisen an AttributeError
# Out:
# 4

# %%
### Constructors
# A better way to define attributes is by using th constructor method __init__.

class Dog:
    def __init__(self,name,age):
        self.name=name
        self.age=age
        
dog1 = Dog('Buddy',4)
print(dog1.name)
print(dog1.age)
# Out:
# Buddy
# 4

# %%
### Instance Methods
# Instance methods are functions defined within a class that operate an instance variables.

class Dog:
    def __init__(self,name,age):
        self.name=name
        self.age=age
    def bark(self):
        print(f"{self.name} says woof")

dog1 = Dog('Buddy', 3)
dog1.bark()
dog2 = Dog('Lucy', 4)
dog2.bark()
# Out:
# Buddy says woof
# Lucy says woof

# %%
### Modeling a Bank Account

class BankAccount:

    def __init__(self,owner,balance=0):
        self.owner=owner
        self.balance=balance

    def deposit(self,amount):
        self.balance += amount
        print(f"{amount} is deposited , new balance is {self.balance}")

    def withdraw(self,amount):
        if amount > self.balance:
            print("Insufficient funds")
        else:
            self.balance -= amount
            print(f"{amount} is withdrawn, new balance is {self.balance}")
            
    def get_balance(self):
        return self.balance
        
account = BankAccount('Krish',9000)
print(account.balance)
account.deposit(1000)
account.withdraw(500)
print(account.get_balance())
# Out:
# 9000
# 1000 is deposited , new balance is 10000
# 500 is withdrawn, new balance is 9500
# 9500
